# %%
pip install selenium
# Out:
# Requirement already satisfied: selenium in f:\softwares\lib\site-packages (4.38.0)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in f:\softwares\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio<1.0,>=0.31.0 in f:\softwares\lib\site-packages (from selenium) (0.32.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in f:\softwares\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.10.5 in f:\softwares\lib\site-packages (from selenium) (2025.11.12)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in f:\softwares\lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in f:\softwares\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in f:\softwares\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (24.3.0)
# Requirement already satisfied: sortedcontainers in f:\softwares\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in f:\softwares\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.7)
# Requirement already satisfied: outcome in f:\softwares\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in f:\softwares\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in f:\softwares\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.17.1)
# Requirement already satisfied: wsproto>=0.14 in f:\softwares\lib\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in f:\softwares\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: pycparser in f:\softwares\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.16.0 in f:\softwares\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import time

# Setup WebDriver
options = Options()
options.add_argument("--start-maximized")  
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")
driver = webdriver.Chrome(options=options)

url = 'https://coinmarketcap.com/'
driver.get(url)
time.sleep(3)  

# Slowly scroll to the bottom of the page
scroll_pause_time = 0.5 
scroll_step = 300  # pixels per scroll
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    for i in range(0, last_height, scroll_step):
        driver.execute_script(f"window.scrollTo(0, {i});")
        time.sleep(scroll_pause_time)
    
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break  
    last_height = new_height

print(" Finished scrolling")



soup = BeautifulSoup(driver.page_source, "html.parser")
driver.quit()

table = soup.find('table', {'class': 'cmc-table'})

rows = table.find_all('tr')
print(f"Found {len(rows)-1} rows (excluding header)")

crypto_data = []

for row in rows[1:]: 
    cols = row.find_all('td')
    if len(cols) >= 10:
        rank = cols[1].text.strip()
        name = cols[2].text.strip()
        price = cols[3].text.strip()
        one_hour_change = cols[4].text.strip()
        twenty_four_hour_change = cols[5].text.strip()
        seven_day_change = cols[6].text.strip()
        market_cap = cols[7].text.strip()
        hr_volume = cols[8].text.strip()
        circulating_supply = cols[9].text.strip()

        crypto_data.append([
            rank, name, price, one_hour_change,
            twenty_four_hour_change, seven_day_change,
            market_cap, hr_volume, circulating_supply
        ])

for coin in crypto_data:
    print(coin)
# Out:
#  Finished scrolling
# Found 101 rows (excluding header)
# ['', 'CoinMarketCap 20 Index DTFCMC20Buy', '$195.73', '0.05%', '2.72%', '1.07%', '$6.65M$6,651,125', '$1,947,4139.94K', '33.97K CMC20']
# ['1', 'BitcoinBTCBuy', '$92,995.94', '0.29%', '2.28%', '1.31%', '$1.86T$1,857,873,347,043', '$40,167,975,806431.34K', '19.97M BTC']
# ['2', 'EthereumETHBuy', '$3,211.13', '0.32%', '3.87%', '3.25%', '$387.91B$387,907,306,245', '$28,660,782,1788.91M', '120.69M ETH']
# ['3', 'TetherUSDTBuy', '$0.9994', '0.00%', '0.02%', '0.02%', '$186.9B$186,897,139,259', '$100,737,252,893100.77B', '186.99B USDT']
# ['4', 'BNBBNBBuy', '$925.25', '0.17%', '2.65%', '2.08%', '$126.17B$126,168,807,022', '$3,132,683,9293.38M', '136.36M BNB']
# ['5', 'XRPXRPBuy', '$2.02', '0.39%', '1.47%', '2.57%', '$122.8B$122,798,473,560', '$4,126,322,3662.04B', '60.78B XRP']
# ['6', 'USDCUSDCBuy', '$0.9999', '0.00%', '0.01%', '0.00%', '$75.81B$75,810,803,015', '$14,659,498,02314.66B', '75.81B USDC']
# ['7', 'SolanaSOLBuy', '$133.91', '0.15%', '5.80%', '6.00%', '$75.74B$75,740,688,473', '$5,468,381,61540.82M', '565.58M SOL']
# ['8', 'TRONTRXBuy', '$0.3086', '0.10%', '3.44%', '3.43%', '$29.23B$29,228,945,702', '$837,615,7352.71B', '94.7B TRX']
# ['9', 'DogecoinDOGEBuy', '$0.1290', '0.03%', '5.60%', '6.85%', '$21.73B$21,725,282,112', '$2,057,608,26415.94B', '168.38B DOGE']
# ['10', 'CardanoADABuy', '$0.3686', '0.12%', '5.79%', '6.66%', '$13.26B$13,255,747,123', '$1,043,288,5142.83B', '35.96B ADA']
# ['11', 'Bitcoin CashBCHBuy', '$589.64', '0.10%', '0.23%', '4.65%', '$11.78B$11,782,908,091', '$476,901,891808.79K', '19.98M BCH']
# ['12', 'MoneroXMRBuy', '$607.79', '0.35%', '3.55%', '0.26%', '$11.21B$11,211,842,419', '$355,827,961574.64K', '18.44M XMR']
# ['13', 'ChainlinkLINKBuy', '$12.84', '0.20%', '6.74%', '2.70%', '$9.09B$9,093,907,881', '$608,789,70647.41M', '708.09M LINK']
# ['14', 'UNUS SED LEOLEOBuy', '$8.90', '0.02%', '2.05%', '1.49%', '$8.21B$8,206,496,501', '$2,902,055325.93K', '921.69M LEO']
# ['15', 'HyperliquidHYPEBuy', '$23.90', '0.51%', '6.79%', '1.12%', '$7.22B$7,220,569,011', '$232,039,9379.71M', '302.07M HYPE']
# ['16', 'StellarXLMBuy', '$0.2177', '0.21%', '3.21%', '1.72%', '$7.06B$7,059,072,356', '$245,000,2921.12B', '32.41B XLM']
# ['17', 'Ethena USDeUSDeBuy', '$0.9994', '0.01%', '0.02%', '0.01%', '$6.47B$6,468,618,225', '$315,589,881315.75M', '6.47B USDe']
# ['18', 'ZcashZECBuy', '$373.51', '0.40%', '3.82%', '7.31%', '$6.16B$6,160,779,785', '$587,544,7811.57M', '16.49M ZEC']
# ['19', 'SuiSUIBuy', '$1.56', '0.51%', '11.83%', '12.49%', '$5.95B$5,951,704,576', '$1,347,298,651858.44M', '3.79B SUI']
# ['20', 'AvalancheAVAXBuy', '$12.70', '0.18%', '6.38%', '7.58%', '$5.47B$5,474,075,510', '$462,407,12936.40M', '430.96M AVAX']
# ['21', 'LitecoinLTCBuy', '$70.98', '0.22%', '5.34%', '7.57%', '$5.45B$5,448,446,178', '$721,279,88210.16M', '76.75M LTC']
# ['22', 'DaiDAIBuy', '$0.9995', '0.01%', '0.02%', '0.03%', '$5.36B$5,363,111,176', '$120,748,193120.79M', '5.36B DAI']
# ['23', 'HederaHBARBuy', '$0.1105', '0.28%', '5.13%', '4.83%', '$4.73B$4,729,088,654', '$208,443,2101.88B', '42.79B HBAR']
# ['24', 'Shiba InuSHIBBuy', '$0.058002', '0.22%', '4.20%', '5.92%', '$4.72B$4,715,352,914', '$144,404,80518.04T', '589.24T SHIB']
# ['25', 'World Liberty FinancialWLFIBuy', '$0.1656', '0.35%', '3.31%', '1.86%', '$4.43B$4,429,354,720', '$114,215,962689.51M', '26.73B WLFI']
# ['26', 'CantonCCBuy', '$0.1099', '0.43%', '6.74%', '24.28%', '$4.12B$4,117,441,024', '$22,248,186202.44M', '37.46B CC']
# ['27', 'ToncoinTONBuy', '$1.59', '0.20%', '7.46%', '8.24%', '$3.88B$3,881,916,195', '$162,721,185102.01M', '2.42B TON']
# ['28', 'CronosCROBuy', '$0.09391', '0.02%', '7.45%', '5.59%', '$3.74B$3,737,480,141', '$26,250,738279.29M', '39.79B CRO']
# ['29', 'PayPal USDPYUSDBuy', '$0.9997', '0.00%', '0.02%', '0.00%', '$3.73B$3,730,502,054', '$63,035,58863.05M', '3.73B PYUSD']
# ['30', 'World Liberty Financial USDUSD1Buy', '$0.9989', '0.00%', '0.01%', '0.06%', '$3.36B$3,364,171,491', '$1,722,779,7381.72B', '3.36B USD1']
# ['31', 'PolkadotDOTBuy', '$2.01', '0.10%', '6.88%', '3.43%', '$3.33B$3,330,449,764', '$241,970,413120.40M', '1.65B DOT']
# ['32', 'UniswapUNIBuy', '$4.98', '0.22%', '6.76%', '7.08%', '$3.17B$3,168,686,272', '$289,323,45457.98M', '635.03M UNI']
# ['33', 'MantleMNTBuy', '$0.9218', '0.08%', '3.58%', '2.84%', '$3B$2,998,597,061', '$187,845,499203.94M', '3.25B MNT']
# ['34', 'BittensorTAOBuy', '$253.64', '0.36%', '6.44%', '10.38%', '$2.69B$2,689,449,935', '$173,277,367683.89K', '10.6M TAO']
# ['35', 'Bitget TokenBGBBuy', '$3.74', '0.12%', '1.18%', '6.03%', '$2.62B$2,616,585,269', '$48,274,72112.90M', '699.43M BGB']
# ['36', 'AaveAAVEBuy', '$163.98', '0.27%', '6.58%', '0.86%', '$2.51B$2,511,749,499', '$357,996,6292.18M', '15.31M AAVE']
# ['37', 'OKBOKBBuy', '$108.83', '0.00%', '4.43%', '2.25%', '$2.29B$2,285,455,741', '$37,951,758348.72K', '21M OKB']
# ['38', 'Internet ComputerICPBuy', '$3.98', '0.83%', '2.84%', '25.87%', '$2.18B$2,182,281,015', '$349,604,09787.95M', '547.35M ICP']
# ['39', 'PepePEPEBuy', '$0.055230', '0.57%', '8.16%', '11.44%', '$2.16B$2,164,183,337', '$611,595,853117.00T', '413.77T PEPE']
# ['40', 'Tether GoldXAUtBuy', '$4,674.00', '0.03%', '1.44%', '1.49%', '$2.05B$2,052,906,984', '$159,217,67234.07K', '439.21K XAUt']
# ['41', 'NEAR ProtocolNEARBuy', '$1.58', '0.28%', '7.89%', '7.16%', '$2.03B$2,033,194,483', '$293,351,934185.58M', '1.28B NEAR']
# ['42', 'MemeCoreMBuy', '$1.57', '0.08%', '0.24%', '6.14%', '$1.98B$1,980,177,991', '$12,736,8088.10M', '1.25B M']
# ['43', 'Ethereum ClassicETCBuy', '$11.95', '0.19%', '5.87%', '3.13%', '$1.86B$1,855,152,597', '$122,788,23610.28M', '155.18M ETC']
# ['44', 'PAX GoldPAXGBuy', '$4,687.62', '0.06%', '1.26%', '1.61%', '$1.8B$1,796,473,194', '$226,752,79248.38K', '383.23K PAXG']
# ['45', 'OndoONDOBuy', '$0.3459', '0.43%', '6.06%', '12.30%', '$1.68B$1,684,608,091', '$139,989,814406.78M', '4.86B ONDO']
# ['46', 'Global DollarUSDGBuy', '$0.9997', '0.01%', '0.00%', '0.03%', '$1.6B$1,600,620,430', '$24,129,07624.13M', '1.6B USDG']
# ['47', 'AsterASTERBuy', '$0.6223', '0.25%', '13.00%', '10.01%', '$1.6B$1,601,883,439', '$338,013,614543.62M', '2.57B ASTER']
# ['48', 'PiPIBuy', '$0.1888', '0.14%', '7.16%', '8.79%', '$1.58B$1,583,221,590', '$28,749,585152.01M', '8.38B PI']
# ['49', 'EthenaENABuy', '$0.1925', '0.78%', '11.15%', '13.17%', '$1.53B$1,531,913,117', '$257,491,8041.33B', '7.95B ENA']
# ['50', 'KuCoin TokenKCSBuy', '$11.21', '0.13%', '2.65%', '2.34%', '$1.48B$1,482,048,351', '$3,186,040283.70K', '132.15M KCS']
# ['51', 'SkySKYBuy', '$0.06418', '0.45%', '0.03%', '15.67%', '$1.48B$1,475,849,780', '$30,202,601470.47M', '22.99B SKY']
# ['52', 'Polygon (prev. MATIC)POLBuy', '$0.1361', '0.27%', '5.20%', '11.24%', '$1.44B$1,438,663,626', '$138,374,4621.01B', '10.56B POL']
# ['53', 'WorldcoinWLDBuy', '$0.5037', '0.28%', '6.85%', '10.87%', '$1.38B$1,384,281,744', '$143,738,123285.67M', '2.74B WLD']
# ['54', 'Ripple USDRLUSDBuy', '$0.9998', '0.00%', '0.01%', '0.04%', '$1.34B$1,335,901,348', '$48,745,55048.75M', '1.33B RLUSD']
# ['55', 'MYX FinanceMYXBuy', '$5.28', '0.12%', '2.28%', '12.75%', '$1.33B$1,328,160,143', '$15,406,6762.91M', '251.47M MYX']
# ['56', 'AptosAPTBuy', '$1.59', '0.11%', '12.77%', '10.09%', '$1.22B$1,221,266,497', '$152,753,77095.59M', '764.1M APT']
# ['57', 'CosmosATOMBuy', '$2.41', '0.65%', '3.96%', '4.59%', '$1.18B$1,179,082,443', '$77,412,29932.13M', '488.64M ATOM']
# ['58', 'KaspaKASBuy', '$0.04259', '0.34%', '3.84%', '8.96%', '$1.16B$1,155,521,677', '$28,150,880660.75M', '27.12B KAS']
# ['59', 'GateTokenGTBuy', '$10.00', '0.02%', '3.19%', '2.60%', '$1.15B$1,152,836,912', '$4,042,475403.24K', '115.18M GT']
# ['60', 'USDDUSDDBuy', '$0.9989', '0.01%', '0.08%', '0.01%', '$1.13B$1,134,319,988', '$4,805,6744.80M', '1.13B USDD']
# ['61', 'ArbitrumARBBuy', '$0.1927', '0.35%', '11.07%', '5.33%', '$1.12B$1,122,993,763', '$195,141,3351.01B', '5.82B ARB']
# ['62', 'MidnightNIGHTBuy', '$0.06423', '1.20%', '7.62%', '4.11%', '$1.07B$1,066,777,531', '$48,697,445743.74M', '16.6B NIGHT']
# ['63', 'AlgorandALGOBuy', '$0.1210', '0.68%', '5.37%', '7.88%', '$1.07B$1,072,533,090', '$50,223,809414.34M', '8.85B ALGO']
# ['64', 'RenderRENDERBuy', '$2.05', '0.14%', '5.30%', '15.09%', '$1.06B$1,064,466,070', '$96,797,90947.16M', '518.67M RENDER']
# ['65', 'QuantQNTBuy', '$86.58', '4.88%', '5.93%', '18.01%', '$1.05B$1,045,372,152', '$44,013,104518.05K', '12.07M QNT']
# ['66', 'FilecoinFILBuy', '$1.37', '0.16%', '9.82%', '6.15%', '$1.02B$1,017,427,691', '$223,297,542161.93M', '738.05M FIL']
# ['67', 'OFFICIAL TRUMPTRUMPBuy', '$4.99', '0.04%', '3.36%', '7.47%', '$999.28M$999,280,949', '$279,824,94556.06M', '199.99M TRUMP']
# ['68', 'DashDASHBuy', '$77.89', '0.68%', '10.97%', '104.52%', '$978.2M$978,203,902', '$693,494,5658.85M', '12.55M DASH']
# ['69', 'VeChainVETBuy', '$0.01081', '0.17%', '7.21%', '5.64%', '$930.26M$930,262,000', '$36,215,0633.34B', '85.98B VET']
# ['70', 'Pump.funPUMPBuy', '$0.002551', '0.82%', '6.67%', '1.68%', '$903.21M$903,210,107', '$210,909,06882.66B', '354B PUMP']
# ['71', 'StoryIPBuy', '$2.51', '0.67%', '5.77%', '9.77%', '$876.89M$876,894,399', '$142,877,80456.75M', '348.76M IP']
# ['72', 'FlareFLRBuy', '$0.01041', '0.41%', '4.14%', '5.81%', '$864.04M$864,043,627', '$13,416,0141.28B', '82.92B FLR']
# ['73', 'BonkBONKBuy', '$0.059241', '0.46%', '9.85%', '11.36%', '$813.21M$813,211,736', '$142,817,61215.45T', '87.99T BONK']
# ['74', 'XDC NetworkXDCBuy', '$0.04181', '0.59%', '2.97%', '11.10%', '$798.16M$798,160,373', '$27,892,698666.86M', '19.08B XDC']
# ['75', 'SeiSEIBuy', '$0.1107', '0.36%', '6.97%', '8.18%', '$732.57M$732,565,621', '$81,828,117738.97M', '6.61B SEI']
# ['76', 'PancakeSwapCAKEBuy', '$2.02', '0.15%', '3.27%', '3.24%', '$675.23M$675,226,817', '$59,236,44129.31M', '334.06M CAKE']
# ['77', 'Pudgy PenguinsPENGUBuy', '$0.01043', '0.00%', '8.18%', '13.33%', '$655.75M$655,753,795', '$209,882,25620.14B', '62.86B PENGU']
# ['78', 'TezosXTZBuy', '$0.6075', '0.58%', '0.69%', '9.13%', '$651.61M$651,613,445', '$52,605,70586.72M', '1.07B XTZ']
# ['79', 'JupiterJUPBuy', '$0.2002', '0.23%', '9.12%', '5.01%', '$638.94M$638,943,129', '$33,633,049168.03M', '3.19B JUP']
# ['80', 'NexoNEXOBuy', '$0.9605', '0.90%', '2.39%', '0.51%', '$620.68M$620,678,141', '$11,688,06312.17M', '646.14M NEXO']
# ['81', 'OptimismOPBuy', '$0.3144', '0.28%', '7.82%', '0.13%', '$611.23M$611,230,388', '$112,276,405356.45M', '1.94B OP']
# ['82', 'StacksSTXBuy', '$0.3256', '0.64%', '8.94%', '16.98%', '$590.89M$590,887,529', '$21,465,60565.74M', '1.81B STX']
# ['83', 'ChilizCHZBuy', '$0.05773', '0.06%', '5.35%', '18.24%', '$590.47M$590,466,387', '$159,001,5152.76B', '10.22B CHZ']
# ['84', 'United StablesUBuy', '$0.9994', '0.01%', '0.03%', '0.00%', '$574.57M$574,569,366', '$24,501,33524.51M', '574.9M U']
# ['85', 'Virtuals ProtocolVIRTUALBuy', '$0.8726', '0.07%', '4.86%', '15.05%', '$572.61M$572,605,836', '$140,661,203161.49M', '656.15M VIRTUAL']
# ['86', 'Curve DAO TokenCRVBuy', '$0.3905', '0.17%', '6.80%', '0.63%', '$568.95M$568,949,916', '$77,353,438198.17M', '1.45B CRV']
# ['87', 'Artificial Superintelligence AllianceFETBuy', '$0.2453', '0.21%', '9.65%', '14.45%', '$564.83M$564,832,503', '$101,846,227415.17M', '2.3B FET']
# ['88', 'ImmutableIMXBuy', '$0.2593', '0.24%', '9.77%', '2.46%', '$515.89M$515,889,734', '$31,372,151121.11M', '1.98B IMX']
# ['89', 'First Digital USDFDUSDBuy', '$0.9988', '0.01%', '0.06%', '0.07%', '$499.06M$499,061,490', '$3,415,363,5913.41B', '499.64M FDUSD']
# ['90', 'TrueUSDTUSDBuy', '$0.9991', '0.01%', '0.06%', '0.03%', '$494.11M$494,112,823', '$14,164,90714.17M', '494.51M TUSD']
# ['91', 'MorphoMORPHOBuy', '$1.29', '0.11%', '4.14%', '0.10%', '$489.2M$489,203,273', '$22,292,00017.23M', '378.41M MORPHO']
# ['92', 'InjectiveINJBuy', '$4.74', '0.59%', '8.56%', '6.89%', '$474.4M$474,397,674', '$68,350,82714.42M', '99.97M INJ']
# ['93', 'Lido DAOLDOBuy', '$0.5496', '0.45%', '9.62%', '10.61%', '$465.32M$465,318,424', '$59,584,348108.43M', '846.56M LDO']
# ['94', 'SPX6900SPXBuy', '$0.4969', '0.51%', '11.26%', '15.35%', '$462.64M$462,640,578', '$16,079,45732.33M', '930.99M SPX']
# ['95', 'LayerZeroZROBuy', '$1.67', '0.03%', '3.06%', '12.93%', '$459.25M$459,251,012', '$45,181,52926.98M', '274.31M ZRO']
# ['96', 'Aerodrome FinanceAEROBuy', '$0.5011', '0.15%', '7.31%', '12.98%', '$458.01M$458,009,295', '$23,492,39946.78M', '913.84M AERO']
# ['97', 'ether.fiETHFIBuy', '$0.6485', '0.49%', '12.73%', '11.76%', '$453.61M$453,606,605', '$61,739,73895.12M', '699.46M ETHFI']
# ['98', 'CelestiaTIABuy', '$0.4931', '0.44%', '12.97%', '9.22%', '$428.46M$428,459,203', '$72,425,709146.90M', '868.89M TIA']
# ['99', 'StarknetSTRKBuy', '$0.08224', '0.01%', '4.15%', '1.02%', '$428.18M$428,176,127', '$67,812,392824.29M', '5.2B STRK']
# ['100', 'FLOKIFLOKIBuy', '$0.00004492', '0.14%', '8.11%', '12.55%', '$428.6M$428,595,979', '$48,085,0451.07T', '9.53T FLOKI']

# %%
# !pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in f:\softwares\lib\site-packages (5.2.0)

# %%
import pyodbc
import pandas as pd

# %%
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=DESKTOP-QQN1OAH;"
    "DATABASE=coinmarketcap;"
    "Trusted_Connection=yes;"
)

cursor = conn.cursor()

insert_query = """
INSERT INTO crypto_prices (
    rank, name, price, one_hour_change,
    twenty_four_hour_change, seven_day_change,
    market_cap, hr_volume, circulating_supply
)
VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)
"""

cursor.fast_executemany = True

cursor.executemany(insert_query, crypto_data)

conn.commit()
cursor.close()
conn.close()
print(" Data inserted successfully")
# Out:
#  Data inserted successfully
